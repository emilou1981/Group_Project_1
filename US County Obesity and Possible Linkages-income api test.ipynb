# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import requests
import xlrd 
import json
import seaborn as sns
from config import api_key
from pandas import DataFrame
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a0eefba35caa> in <module>
#       1 # Dependencies and Setup
#       2 import matplotlib.pyplot as plt
# ----> 3 import plotly.graph_objects as go
#       4 import pandas as pd
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'plotly'

# %%
#import data from url to get the state abbr
url="http://worldpopulationreview.com/static/states/name-abbr.json"
d = requests.get(url).json()

states_abbr = pd.DataFrame(d.items() , columns=["State","State Abbr"])

states_abbr.head()
# Out:
#             State State Abbr
# 0         Alabama         AL
# 1          Alaska         AK
# 2  American Samoa         AS
# 3         Arizona         AZ
# 4        Arkansas         AR

# %%
#import excel file with obesity, unemployment, education
xls = pd.ExcelFile('Resources/2016 County Health Rankings Data - v3.xls')
df = pd.read_excel(xls, 'Ranked Measure Data', skiprows=1)

# %%
df.head()
# Out:
#      FIPS    State   County  # Deaths  Years of Potential Life Lost Rate  \
# 0  1001.0  Alabama  Autauga     809.0                             9215.1
# 1  1003.0  Alabama  Baldwin    2506.0                             7454.6
# 2  1005.0  Alabama  Barbour     410.0                             8499.9
# 3  1007.0  Alabama     Bibb     414.0                            11007.7
# 4  1009.0  Alabama   Blount     876.0                             8655.9
#
#    95% CI - Low  95% CI - High Quartile  % Fair/Poor  95% CI - Low.1  ...  \
# 0        8307.8        10122.3        2         19.4            18.8  ...
# 1        7001.9         7907.3        1         16.0            15.6  ...
# 2        7256.9         9742.8        1         25.7            25.0  ...
# 3        9346.3        12669.1        3         22.0            21.3  ...
# 4        7799.8         9512.0        1         20.7            20.0  ...
#
#    # Workers % Drive Alone  95% CI - Low.20  95% CI - High.20  Quartile.33  \
# 0    24290.0     89.230136        87.152547         91.307725            4
# 1    82134.0     84.071152        82.543906         85.598398            2
# 2     9108.0     83.519982        81.092529         85.947436            2
# 3     7773.0     84.034478        80.071760         87.997196            2
# 4    22168.0     85.073078        82.839898         87.306258            3
#
#   # Workers who Drive Alone  % Long Commute - Drives Alone  95% CI - Low.21  \
# 0                   21674.0                           41.7        37.996787
# 1                   69051.0                           36.8        34.609473
# 2                    7607.0                           35.1        29.689536
# 3                    6532.0                           45.7        38.399757
# 4                   18859.0                           59.0        54.229577
#
#    95% CI - High.21 Quartile.34
# 0         45.403213           3
# 1         38.990527           3
# 2         40.510464           2
# 3         53.000243           4
# 4         63.770423           4
#
# [5 rows x 156 columns]

# %%
#rename columns used for analysis
df.rename(columns={ df.columns[108]: "Unemployment Percent" }, inplace = True)
df.rename(columns={ df.columns[31]: "Obesity Percent" }, inplace = True)
df.rename(columns={ df.columns[102]: "Some College Percent" }, inplace = True)
df.rename(columns={ df.columns[98]: "High School Grad Percent" }, inplace = True)


#merge data
stats_df = pd.merge(states_abbr, df,
                                 how='left', on='State')

stats_df.head()
# Out:
#      State State Abbr    FIPS   County  # Deaths  \
# 0  Alabama         AL  1001.0  Autauga     809.0
# 1  Alabama         AL  1003.0  Baldwin    2506.0
# 2  Alabama         AL  1005.0  Barbour     410.0
# 3  Alabama         AL  1007.0     Bibb     414.0
# 4  Alabama         AL  1009.0   Blount     876.0
#
#    Years of Potential Life Lost Rate  95% CI - Low  95% CI - High Quartile  \
# 0                             9215.1        8307.8        10122.3        2
# 1                             7454.6        7001.9         7907.3        1
# 2                             8499.9        7256.9         9742.8        1
# 3                            11007.7        9346.3        12669.1        3
# 4                             8655.9        7799.8         9512.0        1
#
#    % Fair/Poor  ...  # Workers  % Drive Alone 95% CI - Low.20  \
# 0         19.4  ...    24290.0      89.230136       87.152547
# 1         16.0  ...    82134.0      84.071152       82.543906
# 2         25.7  ...     9108.0      83.519982       81.092529
# 3         22.0  ...     7773.0      84.034478       80.071760
# 4         20.7  ...    22168.0      85.073078       82.839898
#
#    95% CI - High.20  Quartile.33  # Workers who Drive Alone  \
# 0         91.307725            4                    21674.0
# 1         85.598398            2                    69051.0
# 2         85.947436            2                     7607.0
# 3         87.997196            2                     6532.0
# 4         87.306258            3                    18859.0
#
#   % Long Commute - Drives Alone  95% CI - Low.21  95% CI - High.21  \
# 0                          41.7        37.996787         45.403213
# 1                          36.8        34.609473         38.990527
# 2                          35.1        29.689536         40.510464
# 3                          45.7        38.399757         53.000243
# 4                          59.0        54.229577         63.770423
#
#    Quartile.34
# 0            3
# 1            3
# 2            2
# 3            4
# 4            4
#
# [5 rows x 157 columns]

# %%
#clean up data to show only stats in comparision
Unemployment_Percent=stats_df["Unemployment Percent"]
Obesity_Percent=stats_df["Obesity Percent"]
Some_College=stats_df["Some College Percent"]
High_School=stats_df["High School Grad Percent"]
State_Name=stats_df["State"]
County=stats_df["County"]
state_abbr=stats_df["State Abbr"]

#create new Dataframe with just information needed
formatted_df= pd.DataFrame({"State": State_Name,
                        "State Abbr": state_abbr,
                        "County": County,
                        "Unemployment (%)": Unemployment_Percent,
                        "Obesity (%)": Obesity_Percent,
                        "Some College (%)": Some_College,
                        "High School Graduate (%)": High_School
                       })

formatted_df.head()
# Out:
#      State State Abbr   County  Unemployment (%)  Obesity (%)  \
# 0  Alabama         AL  Autauga          5.883047         30.9
# 1  Alabama         AL  Baldwin          6.053720         26.7
# 2  Alabama         AL  Barbour         10.809275         40.8
# 3  Alabama         AL     Bibb          7.137850         40.1
# 4  Alabama         AL   Blount          6.146908         32.4
#
#    Some College (%)  High School Graduate (%)
# 0         56.470750                 83.000000
# 1         62.335918                 80.000000
# 2         43.358568                 80.530303
# 3         48.927875                 81.000000
# 4         49.149934                 84.975362

# %%
#import income from GeoFRED API
url = "https://api.stlouisfed.org/geofred/regional/data?"

# api_key=abcdefghijklmnopqrstuvwxyz123456&series_group=882&date=2013-01-01&region_type=state&units=Dollars&frequency=a&season=NSA


# Store a search term
# seriesid="WIPCPI"
series_group="882"
file_type="json"
region_type="county"
# begin_date = "20160101"
# end_date = "20160130"
date="2016-01-01"
units="Dollars"
frequency="a"
season="NSA"


query_url = f"{url}api_key={api_key}&file_type={file_type}&series_group={series_group}&date={date}&region_type={region_type}&units={units}&frequency={frequency}&season={season}"

# %%
#Retrieve income data
response = requests.get(query_url)

response_json = response.json()

# Print the json (pretty printed)
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "meta": {
#         "data": {
#             "2016": [
#                 {
#                     "code": "01001",
#                     "region": "Autauga County, AL",
#                     "series_id": "PCPI01001",
#                     "value": "39509"
#                 },
#                 {
#                     "code": "01003",
#                     "region": "Baldwin County, AL",
#                     "series_id": "PCPI01003",
#                     "value": "43004"
#                 },
#                 {
#                     "code": "01005",
#                     "region": "Barbour County, AL",
#                     "series_id": "PCPI01005",
#                     "value": "31750"
#                 },
#                 {
#                     "code": "01007",
#                     "region": "Bibb County, AL",
#                     "series_id": "PCPI01007",
#                     "value": "28989"
#                 },
#                 {
#                     "code": "01009",
#                     "region": "Blount County, AL",
#                     "series_id": "PCPI01009",
#                     "value": "32261"
#                 },
#                 {
#                     "code": "01011",
#                     "region": "Bullock County, AL",
#                     "series_id": "PCPI01011",
#                     "value": "26450"
#                 },
#                 {
#                     "code": "01013",
#                     "region": "Butler County, AL",
#                     "series_id": "PCPI01013",
#                     "value": "33888"
#                 },
#                 {
#                     "code": "01015",
#                     "region": "Calhoun County, AL",
#                     "series_id": "PCPI01015",
#                     "value": "34869"
#                 },
#                 {
#                     "code": "01017",
#                     "region": "Chambers County, AL",
#                     "series_id": "PCPI01017",
#                     "value": "32562"
#                 },
#                 {
#                     "code": "01019",
#                     "region": "Cherokee County, AL",
#                     "series_id": "PCPI01019",
#                     "value": "32758"
#                 },
#                 {
#                     "code": "01021",
#                     "region": "Chilton County, AL",
#                     "series_id": "PCPI01021",
#                     "value": "32268"
#                 },
#                 {
#                     "code": "01023",
#                     "region": "Choctaw County, AL",
#                     "series_id": "PCPI01023",
#                     "value": "36232"
#                 },
#                 {
#                     "code": "01025",
#                     "region": "Clarke County, AL",
#                     "series_id": "PCPI01025",
#                     "value": "34476"
#                 },
#                 {
#                     "code": "01027",
#                     "region": "Clay County, AL",
#                     "series_id": "PCPI01027",
#                     "value": "31314"
#                 },
#                 {
#                     "code": "01029",
#                     "region": "Cleburne County, AL",
#                     "series_id": "PCPI01029",
#                     "value": "33917"
#                 },
#                 {
#                     "code": "01031",
#                     "region": "Coffee County, AL",
#                     "series_id": "PCPI01031",
#                     "value": "40319"
#                 },
#                 {
#                     "code": "01033",
#                     "region": "Colbert County, AL",
#                     "series_id": "PCPI01033",
#                     "value": "36452"
#                 },
#                 {
#                     "code": "01035",
#                     "region": "Conecuh County, AL",
#                     "series_id": "PCPI01035",
#                     "value": "30536"
#                 },
#                 {
#                     "code": "01037",
#                     "region": "Coosa County, AL",
#                     "series_id": "PCPI01037",
#                     "value": "29284"
#                 },
#                 {
#                     "code": "01039",
#                     "region": "Covington County, AL",
#                     "series_id": "PCPI01039",
#                     "value": "32971"
#                 },
#                 {
#                     "code": "01041",
#                     "region": "Crenshaw County, AL",
#                     "series_id": "PCPI01041",
#                     "value": "34596"
#                 },
#                 {
#                     "code": "01043",
#                     "region": "Cullman County, AL",
#                     "series_id": "PCPI01043",
#                     "value": "36721"
#                 },
#                 {
#                     "code": "01045",
#                     "region": "Dale County, AL",
#                     "series_id": "PCPI01045",
#                     "value": "34559"
#                 },
#                 {
#                     "code": "01047",
#                     "region": "Dallas County, AL",
#                     "series_id": "PCPI01047",
#                     "value": "33691"
#                 },
#                 {
#                     "code": "01049",
#                     "region": "DeKalb County, AL",
#                     "series_id": "PCPI01049",
#                     "value": "29405"
#                 },
#                 {
#                     "code": "01051",
#                     "region": "Elmore County, AL",
#                     "series_id": "PCPI01051",
#                     "value": "39575"
#                 },
#                 {
#                     "code": "01053",
#                     "region": "Escambia County, AL",
#                     "series_id": "PCPI01053",
#                     "value": "30772"
#                 },
#                 {
#                     "code": "01055",
#                     "region": "Etowah County, AL",
#                     "series_id": "PCPI01055",
#                     "value": "34783"
#                 },
#                 {
#                     "code": "01057",
#                     "region": "Fayette County, AL",
#                     "series_id": "PCPI01057",
#                     "value": "32394"
#                 },
#                 {
#                     "code": "01059",
#                     "region": "Franklin County, AL",
#                     "series_id": "PCPI01059",
#                     "value": "31153"
#                 },
#                 {
#                     "code": "01061",
#                     "region": "Geneva County, AL",
#                     "series_id": "PCPI01061",
#                     "value": "32627"
#                 },
#                 {
#                     "code": "01063",
#                     "region": "Greene County, AL",
#                     "series_id": "PCPI01063",
#                     "value": "31084"
#                 },
#                 {
#                     "code": "01065",
#                     "region": "Hale County, AL",
#                     "series_id": "PCPI01065",
#                     "value": "34661"
#                 },
#                 {
#                     "code": "01067",
#                     "region": "Henry County, AL",
#                     "series_id": "PCPI01067",
#                     "value": "37632"
#                 },
#                 {
#                     "code": "01069",
#                     "region": "Houston County, AL",
#                     "series_id": "PCPI01069",
#                     "value": "39511"
#                 },
#                 {
#                     "code": "01071",
#                     "region": "Jackson County, AL",
#                     "series_id": "PCPI01071",
#                     "value": "34198"
#                 },
#                 {
#                     "code": "01073",
#                     "region": "Jefferson County, AL",
#                     "series_id": "PCPI01073",
#                     "value": "49678"
#                 },
#                 {
#                     "code": "01075",
#                     "region": "Lamar County, AL",
#                     "series_id": "PCPI01075",
#                     "value": "31809"
#                 },
#                 {
#                     "code": "01077",
#                     "region": "Lauderdale County, AL",
#                     "series_id": "PCPI01077",
#                     "value": "35412"
#                 },
#                 {
#                     "code": "01079",
#                     "region": "Lawrence County, AL",
#                     "series_id": "PCPI01079",
#                     "value": "31102"
#                 },
#                 {
#                     "code": "01081",
#                     "region": "Lee County, AL",
#                     "series_id": "PCPI01081",
#                     "value": "35758"
#                 },
#                 {
#                     "code": "01083",
#                     "region": "Limestone County, AL",
#                     "series_id": "PCPI01083",
#                     "value": "39080"
#                 },
#                 {
#                     "code": "01085",
#                     "region": "Lowndes County, AL",
#                     "series_id": "PCPI01085",
#                     "value": "37203"
#                 },
#                 {
#                     "code": "01087",
#                     "region": "Macon County, AL",
#                     "series_id": "PCPI01087",
#                     "value": "30638"
#                 },
#                 {
#                     "code": "01089",
#                     "region": "Madison County, AL",
#                     "series_id": "PCPI01089",
#                     "value": "48076"
#                 },
#                 {
#                     "code": "01091",
#                     "region": "Marengo County, AL",
#                     "series_id": "PCPI01091",
#                     "value": "36766"
#                 },
#                 {
#                     "code": "01093",
#                     "region": "Marion County, AL",
#                     "series_id": "PCPI01093",
#                     "value": "30577"
#                 },
#                 {
#                     "code": "01095",
#                     "region": "Marshall County, AL",
#                     "series_id": "PCPI01095",
#                     "value": "33776"
#                 },
#                 {
#                     "code": "01097",
#                     "region": "Mobile County, AL",
#                     "series_id": "PCPI01097",
#                     "value": "36136"
#                 },
#                 {
#                     "code": "01099",
#                     "region": "Monroe County, AL",
#                     "series_id": "PCPI01099",
#                     "value": "31352"
#                 },
#                 {
#                     "code": "01101",
#                     "region": "Montgomery County, AL",
#                     "series_id": "PCPI01101",
#                     "value": "41484"
#                 },
#                 {
#                     "code": "01103",
#                     "region": "Morgan County, AL",
#                     "series_id": "PCPI01103",
#                     "value": "37207"
#                 },
#                 {
#                     "code": "01105",
#                     "region": "Perry County, AL",
#                     "series_id": "PCPI01105",
#                     "value": "28909"
#                 },
#                 {
#                     "code": "01107",
#                     "region": "Pickens County, AL",
#                     "series_id": "PCPI01107",
#                     "value": "30531"
#                 },
#                 {
#                     "code": "01109",
#                     "region": "Pike County, AL",
#                     "series_id": "PCPI01109",
#                     "value": "35168"
#                 },
#                 {
#                     "code": "01111",
#                     "region": "Randolph County, AL",
#                     "series_id": "PCPI01111",
#                     "value": "30630"
#                 },
#                 {
#                     "code": "01113",
#                     "region": "Russell County, AL",
#                     "series_id": "PCPI01113",
#                     "value": "30773"
#                 },
#                 {
#                     "code": "01115",
#                     "region": "St. Clair County, AL",
#                     "series_id": "PCPI01115",
#                     "value": "35638"
#                 },
#                 {
#                     "code": "01117",
#                     "region": "Shelby County, AL",
#                     "series_id": "PCPI01117",
#                     "value": "50640"
#                 },
#                 {
#                     "code": "01119",
#                     "region": "Sumter County, AL",
#                     "series_id": "PCPI01119",
#                     "value": "31202"
#                 },
#                 {
#                     "code": "01121",
#                     "region": "Talladega County, AL",
#                     "series_id": "PCPI01121",
#                     "value": "32613"
#                 },
#                 {
#                     "code": "01123",
#                     "region": "Tallapoosa County, AL",
#                     "series_id": "PCPI01123",
#                     "value": "38217"
#                 },
#                 {
#                     "code": "01125",
#                     "region": "Tuscaloosa County, AL",
#                     "series_id": "PCPI01125",
#                     "value": "36211"
#                 },
#                 {
#                     "code": "01127",
#                     "region": "Walker County, AL",
#                     "series_id": "PCPI01127",
#                     "value": "37090"
#                 },
#                 {
#                     "code": "01129",
#                     "region": "Washington County, AL",
#                     "series_id": "PCPI01129",
#                     "value": "34256"
#                 },
#                 {
#                     "code": "01131",
#                     "region": "Wilcox County, AL",
#                     "series_id": "PCPI01131",
#                     "value": "30215"
#                 },
#                 {
#                     "code": "01133",
#                     "region": "Winston County, AL",
#                     "series_id": "PCPI01133",
#                     "value": "32198"
#                 },
#                 {
#                     "code": "02013",
#                     "region": "Aleutians East Borough, AK",
#                     "series_id": "PCPI02013",
#                     "value": "58254"
#                 },
#                 {
#                     "code": "02016",
#                     "region": "Aleutians West CA, AK",
#                     "series_id": "PCPI02016",
#                     "value": "54893"
#                 },
#                 {
#                     "code": "02020",
#                     "region": "Anchorage Muny, AK",
#                     "series_id": "PCPI02020",
#                     "value": "61958"
#                 },
#                 {
#                     "code": "02050",
#                     "region": "Bethel CA, AK",
#                     "series_id": "PCPI02050",
#                     "value": "41871"
#                 },
#                 {
#                     "code": "02060",
#                     "region": "Bristol Bay Borough, AK",
#                     "series_id": "PCPI02060",
#                     "value": "119811"
#                 },
#                 {
#                     "code": "02068",
#                     "region": "Denali Borough, AK",
#                     "series_id": "PCPI02068",
#                     "value": "76064"
#                 },
#                 {
#                     "code": "02070",
#                     "region": "Dillingham CA, AK",
#                     "series_id": "PCPI02070",
#                     "value": "55516"
#                 },
#                 {
#                     "code": "02090",
#                     "region": "Fairbanks North Star Borough, AK",
#                     "series_id": "PCPI02090",
#                     "value": "52843"
#                 },
#                 {
#                     "code": "02100",
#                     "region": "Haines Borough, AK",
#                     "series_id": "PCPI02100",
#                     "value": "56593"
#                 },
#                 {
#                     "code": "02105",
#                     "region": "Hoonah-Angoon CA, AK",
#                     "series_id": "PCPI02105",
#                     "value": "53531"
#                 },
#                 {
#                     "code": "02110",
#                     "region": "Juneau Cty&Bor, AK",
#                     "series_id": "PCPI02110",
#                     "value": "64319"
#                 },
#                 {
#                     "code": "02122",
#                     "region": "Kenai Peninsula Borough, AK",
#                     "series_id": "PCPI02122",
#                     "value": "48923"
#                 },
#                 {
#                     "code": "02130",
#                     "region": "Ketchikan Gateway Borough, AK",
#                     "series_id": "PCPI02130",
#                     "value": "63894"
#                 },
#                 {
#                     "code": "02150",
#                     "region": "Kodiak Island Borough, AK",
#                     "series_id": "PCPI02150",
#                     "value": "58066"
#                 },
#                 {
#                     "code": "02164",
#                     "region": "Lake and Peninsula Borough, AK",
#                     "series_id": "PCPI02164",
#                     "value": "54702"
#                 },
#                 {
#                     "code": "02170",
#                     "region": "Matanuska-Susitna Borough, AK",
#                     "series_id": "PCPI02170",
#                     "value": "44454"
#                 },
#                 {
#                     "code": "02180",
#                     "region": "Nome CA, AK",
#                     "series_id": "PCPI02180",
#                     "value": "48472"
#                 },
#                 {
#                     "code": "02185",
#                     "region": "North Slope Borough, AK",
#                     "series_id": "PCPI02185",
#                     "value": "89941"
#                 },
#                 {
#                     "code": "02188",
#                     "region": "Northwest Arctic Borough, AK",
#                     "series_id": "PCPI02188",
#                     "value": "44519"
#                 },
#                 {
#                     "code": "02195",
#                     "region": "Petersburg CA, AK",
#                     "series_id": "PCPI02195",
#                     "value": "63098"
#                 },
#                 {
#                     "code": "02198",
#                     "region": "Prince of Wales-Hyder CA, AK",
#                     "series_id": "PCPI02198",
#                     "value": "39273"
#                 },
#                 {
#                     "code": "02220",
#                     "region": "Sitka Cty&Bor, AK",
#                     "series_id": "PCPI02220",
#                     "value": "61931"
#                 },
#                 {
#                     "code": "02230",
#                     "region": "Skagway Muny, AK",
#                     "series_id": "PCPI02230",
#                     "value": "73673"
#                 },
#                 {
#                     "code": "02240",
#                     "region": "Southeast Fairbanks CA, AK",
#                     "series_id": "PCPI02240",
#                     "value": "46995"
#                 },
#                 {
#                     "code": "02261",
#                     "region": "Valdez-Cordova CA, AK",
#                     "series_id": "PCPI02261",
#                     "value": "56960"
#                 },
#                 {
#                     "code": "02270",
#                     "region": "Wade Hampton CA, AK",
#                     "series_id": "PCPI02270",
#                     "value": "30555"
#                 },
#                 {
#                     "code": "02275",
#                     "region": "Wrangell Cty&Bor, AK",
#                     "series_id": "PCPI02275",
#                     "value": "44748"
#                 },
#                 {
#                     "code": "02282",
#                     "region": "Yakutat Cty&Bor, AK",
#                     "series_id": "PCPI02282",
#                     "value": "53897"
#                 },
#                 {
#                     "code": "02290",
#                     "region": "Yukon-Koyukuk CA, AK",
#                     "series_id": "PCPI02290",
#                     "value": "54535"
#                 },
#                 {
#                     "code": "04001",
#                     "region": "Apache County, AZ",
#                     "series_id": "PCPI04001",
#                     "value": "31385"
#                 },
#                 {
#                     "code": "04003",
#                     "region": "Cochise County, AZ",
#                     "series_id": "PCPI04003",
#                     "value": "37722"
#                 },
#                 {
#                     "code": "04005",
#                     "region": "Coconino County, AZ",
#                     "series_id": "PCPI04005",
#                     "value": "44289"
#                 },
#                 {
#                     "code": "04007",
#                     "region": "Gila County, AZ",
#                     "series_id": "PCPI04007",
#                     "value": "36293"
#                 },
#                 {
#                     "code": "04009",
#                     "region": "Graham County, AZ",
#                     "series_id": "PCPI04009",
#                     "value": "29421"
#                 },
#                 {
#                     "code": "04011",
#                     "region": "Greenlee County, AZ",
#                     "series_id": "PCPI04011",
#                     "value": "33843"
#                 },
#                 {
#                     "code": "04012",
#                     "region": "La Paz County, AZ",
#                     "series_id": "PCPI04012",
#                     "value": "29644"
#                 },
#                 {
#                     "code": "04013",
#                     "region": "Maricopa County, AZ",
#                     "series_id": "PCPI04013",
#                     "value": "43845"
#                 },
#                 {
#                     "code": "04015",
#                     "region": "Mohave County, AZ",
#                     "series_id": "PCPI04015",
#                     "value": "30030"
#                 },
#                 {
#                     "code": "04017",
#                     "region": "Navajo County, AZ",
#                     "series_id": "PCPI04017",
#                     "value": "30093"
#                 },
#                 {
#                     "code": "04019",
#                     "region": "Pima County, AZ",
#                     "series_id": "PCPI04019",
#                     "value": "39889"
#                 },
#                 {
#                     "code": "04021",
#                     "region": "Pinal County, AZ",
#                     "series_id": "PCPI04021",
#                     "value": "28492"
#                 },
#                 {
#                     "code": "04023",
#                     "region": "Santa Cruz County, AZ",
#                     "series_id": "PCPI04023",
#                     "value": "34917"
#                 },
#                 {
#                     "code": "04025",
#                     "region": "Yavapai County, AZ",
#                     "series_id": "PCPI04025",
#                     "value": "36269"
#                 },
#                 {
#                     "code": "04027",
#                     "region": "Yuma County, AZ",
#                     "series_id": "PCPI04027",
#                     "value": "33259"
#                 },
#                 {
#                     "code": "05001",
#                     "region": "Arkansas County, AR",
#                     "series_id": "PCPI05001",
#                     "value": "43275"
#                 },
#                 {
#                     "code": "05003",
#                     "region": "Ashley County, AR",
#                     "series_id": "PCPI05003",
#                     "value": "32883"
#                 },
#                 {
#                     "code": "05005",
#                     "region": "Baxter County, AR",
#                     "series_id": "PCPI05005",
#                     "value": "34191"
#                 },
#                 {
#                     "code": "05007",
#                     "region": "Benton County, AR",
#                     "series_id": "PCPI05007",
#                     "value": "79857"
#                 },
#                 {
#                     "code": "05009",
#                     "region": "Boone County, AR",
#                     "series_id": "PCPI05009",
#                     "value": "33260"
#                 },
#                 {
#                     "code": "05011",
#                     "region": "Bradley County, AR",
#                     "series_id": "PCPI05011",
#                     "value": "36121"
#                 },
#                 {
#                     "code": "05013",
#                     "region": "Calhoun County, AR",
#                     "series_id": "PCPI05013",
#                     "value": "32195"
#                 },
#                 {
#                     "code": "05015",
#                     "region": "Carroll County, AR",
#                     "series_id": "PCPI05015",
#                     "value": "30969"
#                 },
#                 {
#                     "code": "05017",
#                     "region": "Chicot County, AR",
#                     "series_id": "PCPI05017",
#                     "value": "34384"
#                 },
#                 {
#                     "code": "05019",
#                     "region": "Clark County, AR",
#                     "series_id": "PCPI05019",
#                     "value": "33196"
#                 },
#                 {
#                     "code": "05021",
#                     "region": "Clay County, AR",
#                     "series_id": "PCPI05021",
#                     "value": "31612"
#                 },
#                 {
#                     "code": "05023",
#                     "region": "Cleburne County, AR",
#                     "series_id": "PCPI05023",
#                     "value": "35036"
#                 },
#                 {
#                     "code": "05025",
#                     "region": "Cleveland County, AR",
#                     "series_id": "PCPI05025",
#                     "value": "35955"
#                 },
#                 {
#                     "code": "05027",
#                     "region": "Columbia County, AR",
#                     "series_id": "PCPI05027",
#                     "value": "34254"
#                 },
#                 {
#                     "code": "05029",
#                     "region": "Conway County, AR",
#                     "series_id": "PCPI05029",
#                     "value": "35951"
#                 },
#                 {
#                     "code": "05031",
#                     "region": "Craighead County, AR",
#                     "series_id": "PCPI05031",
#                     "value": "35304"
#                 },
#                 {
#                     "code": "05033",
#                     "region": "Crawford County, AR",
#                     "series_id": "PCPI05033",
#                     "value": "31271"
#                 },
#                 {
#                     "code": "05035",
#                     "region": "Crittenden County, AR",
#                     "series_id": "PCPI05035",
#                     "value": "34491"
#                 },
#                 {
#                     "code": "05037",
#                     "region": "Cross County, AR",
#                     "series_id": "PCPI05037",
#                     "value": "32733"
#                 },
#                 {
#                     "code": "05039",
#                     "region": "Dallas County, AR",
#                     "series_id": "PCPI05039",
#                     "value": "32026"
#                 },
#                 {
#                     "code": "05041",
#                     "region": "Desha County, AR",
#                     "series_id": "PCPI05041",
#                     "value": "35556"
#                 },
#                 {
#                     "code": "05043",
#                     "region": "Drew County, AR",
#                     "series_id": "PCPI05043",
#                     "value": "33953"
#                 },
#                 {
#                     "code": "05045",
#                     "region": "Faulkner County, AR",
#                     "series_id": "PCPI05045",
#                     "value": "35320"
#                 },
#                 {
#                     "code": "05047",
#                     "region": "Franklin County, AR",
#                     "series_id": "PCPI05047",
#                     "value": "31786"
#                 },
#                 {
#                     "code": "05049",
#                     "region": "Fulton County, AR",
#                     "series_id": "PCPI05049",
#                     "value": "26717"
#                 },
#                 {
#                     "code": "05051",
#                     "region": "Garland County, AR",
#                     "series_id": "PCPI05051",
#                     "value": "36834"
#                 },
#                 {
#                     "code": "05053",
#                     "region": "Grant County, AR",
#                     "series_id": "PCPI05053",
#                     "value": "36146"
#                 },
#                 {
#                     "code": "05055",
#                     "region": "Greene County, AR",
#                     "series_id": "PCPI05055",
#                     "value": "32095"
#                 },
#                 {
#                     "code": "05057",
#                     "region": "Hempstead County, AR",
#                     "series_id": "PCPI05057",
#                     "value": "29444"
#                 },
#                 {
#                     "code": "05059",
#                     "region": "Hot Spring County, AR",
#                     "series_id": "PCPI05059",
#                     "value": "28633"
#                 },
#                 {
#                     "code": "05061",
#                     "region": "Howard County, AR",
#                     "series_id": "PCPI05061",
#                     "value": "32488"
#                 },
#                 {
#                     "code": "05063",
#                     "region": "Independence County, AR",
#                     "series_id": "PCPI05063",
#                     "value": "32643"
#                 },
#                 {
#                     "code": "05065",
#                     "region": "Izard County, AR",
#                     "series_id": "PCPI05065",
#                     "value": "28604"
#                 },
#                 {
#                     "code": "05067",
#                     "region": "Jackson County, AR",
#                     "series_id": "PCPI05067",
#                     "value": "33179"
#                 },
#                 {
#                     "code": "05069",
#                     "region": "Jefferson County, AR",
#                     "series_id": "PCPI05069",
#                     "value": "33092"
#                 },
#                 {
#                     "code": "05071",
#                     "region": "Johnson County, AR",
#                     "series_id": "PCPI05071",
#                     "value": "27806"
#                 },
#                 {
#                     "code": "05073",
#                     "region": "Lafayette County, AR",
#                     "series_id": "PCPI05073",
#                     "value": "34177"
#                 },
#                 {
#                     "code": "05075",
#                     "region": "Lawrence County, AR",
#                     "series_id": "PCPI05075",
#                     "value": "31525"
#                 },
#                 {
#                     "code": "05077",
#                     "region": "Lee County, AR",
#                     "series_id": "PCPI05077",
#                     "value": "26822"
#                 },
#                 {
#                     "code": "05079",
#                     "region": "Lincoln County, AR",
#                     "series_id": "PCPI05079",
#                     "value": "25400"
#                 },
#                 {
#                     "code": "05081",
#                     "region": "Little River County, AR",
#                     "series_id": "PCPI05081",
#                     "value": "33119"
#                 },
#                 {
#                     "code": "05083",
#                     "region": "Logan County, AR",
#                     "series_id": "PCPI05083",
#                     "value": "31992"
#                 },
#                 {
#                     "code": "05085",
#                     "region": "Lonoke County, AR",
#                     "series_id": "PCPI05085",
#                     "value": "36880"
#                 },
#                 {
#                     "code": "05087",
#                     "region": "Madison County, AR",
#                     "series_id": "PCPI05087",
#                     "value": "33281"
#                 },
#                 {
#                     "code": "05089",
#                     "region": "Marion County, AR",
#                     "series_id": "PCPI05089",
#                     "value": "28573"
#                 },
#                 {
#                     "code": "05091",
#                     "region": "Miller County, AR",
#                     "series_id": "PCPI05091",
#                     "value": "31849"
#                 },
#                 {
#                     "code": "05093",
#                     "region": "Mississippi County, AR",
#                     "series_id": "PCPI05093",
#                     "value": "28013"
#                 },
#                 {
#                     "code": "05095",
#                     "region": "Monroe County, AR",
#                     "series_id": "PCPI05095",
#                     "value": "31245"
#                 },
#                 {
#                     "code": "05097",
#                     "region": "Montgomery County, AR",
#                     "series_id": "PCPI05097",
#                     "value": "27986"
#                 },
#                 {
#                     "code": "05099",
#                     "region": "Nevada County, AR",
#                     "series_id": "PCPI05099",
#                     "value": "31667"
#                 },
#                 {
#                     "code": "05101",
#                     "region": "Newton County, AR",
#                     "series_id": "PCPI05101",
#                     "value": "27151"
#                 },
#                 {
#                     "code": "05103",
#                     "region": "Ouachita County, AR",
#                     "series_id": "PCPI05103",
#                     "value": "34154"
#                 },
#                 {
#                     "code": "05105",
#                     "region": "Perry County, AR",
#                     "series_id": "PCPI05105",
#                     "value": "32590"
#                 },
#                 {
#                     "code": "05107",
#                     "region": "Phillips County, AR",
#                     "series_id": "PCPI05107",
#                     "value": "28556"
#                 },
#                 {
#                     "code": "05109",
#                     "region": "Pike County, AR",
#                     "series_id": "PCPI05109",
#                     "value": "30011"
#                 },
#                 {
#                     "code": "05111",
#                     "region": "Poinsett County, AR",
#                     "series_id": "PCPI05111",
#                     "value": "29285"
#                 },
#                 {
#                     "code": "05113",
#                     "region": "Polk County, AR",
#                     "series_id": "PCPI05113",
#                     "value": "28065"
#                 },
#                 {
#                     "code": "05115",
#                     "region": "Pope County, AR",
#                     "series_id": "PCPI05115",
#                     "value": "32873"
#                 },
#                 {
#                     "code": "05117",
#                     "region": "Prairie County, AR",
#                     "series_id": "PCPI05117",
#                     "value": "32202"
#                 },
#                 {
#                     "code": "05119",
#                     "region": "Pulaski County, AR",
#                     "series_id": "PCPI05119",
#                     "value": "47532"
#                 },
#                 {
#                     "code": "05121",
#                     "region": "Randolph County, AR",
#                     "series_id": "PCPI05121",
#                     "value": "30033"
#                 },
#                 {
#                     "code": "05123",
#                     "region": "St. Francis County, AR",
#                     "series_id": "PCPI05123",
#                     "value": "25881"
#                 },
#                 {
#                     "code": "05125",
#                     "region": "Saline County, AR",
#                     "series_id": "PCPI05125",
#                     "value": "39447"
#                 },
#                 {
#                     "code": "05127",
#                     "region": "Scott County, AR",
#                     "series_id": "PCPI05127",
#                     "value": "28425"
#                 },
#                 {
#                     "code": "05129",
#                     "region": "Searcy County, AR",
#                     "series_id": "PCPI05129",
#                     "value": "26549"
#                 },
#                 {
#                     "code": "05131",
#                     "region": "Sebastian County, AR",
#                     "series_id": "PCPI05131",
#                     "value": "39270"
#                 },
#                 {
#                     "code": "05133",
#                     "region": "Sevier County, AR",
#                     "series_id": "PCPI05133",
#                     "value": "29395"
#                 },
#                 {
#                     "code": "05135",
#                     "region": "Sharp County, AR",
#                     "series_id": "PCPI05135",
#                     "value": "30691"
#                 },
#                 {
#                     "code": "05137",
#                     "region": "Stone County, AR",
#                     "series_id": "PCPI05137",
#                     "value": "28241"
#                 },
#                 {
#                     "code": "05139",
#                     "region": "Union County, AR",
#                     "series_id": "PCPI05139",
#                     "value": "39090"
#                 },
#                 {
#                     "code": "05141",
#                     "region": "Van Buren County, AR",
#                     "series_id": "PCPI05141",
#                     "value": "29527"
#                 },
#                 {
#                     "code": "05143",
#                     "region": "Washington County, AR",
#                     "series_id": "PCPI05143",
#                     "value": "37453"
#                 },
#                 {
#                     "code": "05145",
#                     "region": "White County, AR",
#                     "series_id": "PCPI05145",
#                     "value": "32971"
#                 },
#                 {
#                     "code": "05147",
#                     "region": "Woodruff County, AR",
#                     "series_id": "PCPI05147",
#                     "value": "32920"
#                 },
#                 {
#                     "code": "05149",
#                     "region": "Yell County, AR",
#                     "series_id": "PCPI05149",
#                     "value": "30502"
#                 },
#                 {
#                     "code": "06001",
#                     "region": "Alameda County, CA",
#                     "series_id": "PCPI06001",
#                     "value": "67356"
#                 },
#                 {
#                     "code": "06003",
#                     "region": "Alpine County, CA",
#                     "series_id": "PCPI06003",
#                     "value": "74512"
#                 },
#                 {
#                     "code": "06005",
#                     "region": "Amador County, CA",
#                     "series_id": "PCPI06005",
#                     "value": "42723"
#                 },
#                 {
#                     "code": "06007",
#                     "region": "Butte County, CA",
#                     "series_id": "PCPI06007",
#                     "value": "41931"
#                 },
#                 {
#                     "code": "06009",
#                     "region": "Calaveras County, CA",
#                     "series_id": "PCPI06009",
#                     "value": "45558"
#                 },
#                 {
#                     "code": "06011",
#                     "region": "Colusa County, CA",
#                     "series_id": "PCPI06011",
#                     "value": "45239"
#                 },
#                 {
#                     "code": "06013",
#                     "region": "Contra Costa County, CA",
#                     "series_id": "PCPI06013",
#                     "value": "72195"
#                 },
#                 {
#                     "code": "06015",
#                     "region": "Del Norte County, CA",
#                     "series_id": "PCPI06015",
#                     "value": "36000"
#                 },
#                 {
#                     "code": "06017",
#                     "region": "El Dorado County, CA",
#                     "series_id": "PCPI06017",
#                     "value": "62699"
#                 },
#                 {
#                     "code": "06019",
#                     "region": "Fresno County, CA",
#                     "series_id": "PCPI06019",
#                     "value": "40214"
#                 },
#                 {
#                     "code": "06021",
#                     "region": "Glenn County, CA",
#                     "series_id": "PCPI06021",
#                     "value": "44014"
#                 },
#                 {
#                     "code": "06023",
#                     "region": "Humboldt County, CA",
#                     "series_id": "PCPI06023",
#                     "value": "45119"
#                 },
#                 {
#                     "code": "06025",
#                     "region": "Imperial County, CA",
#                     "series_id": "PCPI06025",
#                     "value": "35118"
#                 },
#                 {
#                     "code": "06027",
#                     "region": "Inyo County, CA",
#                     "series_id": "PCPI06027",
#                     "value": "57966"
#                 },
#                 {
#                     "code": "06029",
#                     "region": "Kern County, CA",
#                     "series_id": "PCPI06029",
#                     "value": "37844"
#                 },
#                 {
#                     "code": "06031",
#                     "region": "Kings County, CA",
#                     "series_id": "PCPI06031",
#                     "value": "33462"
#                 },
#                 {
#                     "code": "06033",
#                     "region": "Lake County, CA",
#                     "series_id": "PCPI06033",
#                     "value": "40128"
#                 },
#                 {
#                     "code": "06035",
#                     "region": "Lassen County, CA",
#                     "series_id": "PCPI06035",
#                     "value": "36310"
#                 },
#                 {
#                     "code": "06037",
#                     "region": "Los Angeles County, CA",
#                     "series_id": "PCPI06037",
#                     "value": "56851"
#                 },
#                 {
#                     "code": "06039",
#                     "region": "Madera County, CA",
#                     "series_id": "PCPI06039",
#                     "value": "37121"
#                 },
#                 {
#                     "code": "06041",
#                     "region": "Marin County, CA",
#                     "series_id": "PCPI06041",
#                     "value": "117552"
#                 },
#                 {
#                     "code": "06043",
#                     "region": "Mariposa County, CA",
#                     "series_id": "PCPI06043",
#                     "value": "48701"
#                 },
#                 {
#                     "code": "06045",
#                     "region": "Mendocino County, CA",
#                     "series_id": "PCPI06045",
#                     "value": "46320"
#                 },
#                 {
#                     "code": "06047",
#                     "region": "Merced County, CA",
#                     "series_id": "PCPI06047",
#                     "value": "36868"
#                 },
#                 {
#                     "code": "06049",
#                     "region": "Modoc County, CA",
#                     "series_id": "PCPI06049",
#                     "value": "43207"
#                 },
#                 {
#                     "code": "06051",
#                     "region": "Mono County, CA",
#                     "series_id": "PCPI06051",
#                     "value": "47003"
#                 },
#                 {
#                     "code": "06053",
#                     "region": "Monterey County, CA",
#                     "series_id": "PCPI06053",
#                     "value": "52316"
#                 },
#                 {
#                     "code": "06055",
#                     "region": "Napa County, CA",
#                     "series_id": "PCPI06055",
#                     "value": "67480"
#                 },
#                 {
#                     "code": "06057",
#                     "region": "Nevada County, CA",
#                     "series_id": "PCPI06057",
#                     "value": "57955"
#                 },
#                 {
#                     "code": "06059",
#                     "region": "Orange County, CA",
#                     "series_id": "PCPI06059",
#                     "value": "62763"
#                 },
#                 {
#                     "code": "06061",
#                     "region": "Placer County, CA",
#                     "series_id": "PCPI06061",
#                     "value": "61566"
#                 },
#                 {
#                     "code": "06063",
#                     "region": "Plumas County, CA",
#                     "series_id": "PCPI06063",
#                     "value": "48704"
#                 },
#                 {
#                     "code": "06065",
#                     "region": "Riverside County, CA",
#                     "series_id": "PCPI06065",
#                     "value": "37827"
#                 },
#                 {
#                     "code": "06067",
#                     "region": "Sacramento County, CA",
#                     "series_id": "PCPI06067",
#                     "value": "48850"
#                 },
#                 {
#                     "code": "06069",
#                     "region": "San Benito County, CA",
#                     "series_id": "PCPI06069",
#                     "value": "48383"
#                 },
#                 {
#                     "code": "06071",
#                     "region": "San Bernardino County, CA",
#                     "series_id": "PCPI06071",
#                     "value": "37514"
#                 },
#                 {
#                     "code": "06073",
#                     "region": "San Diego County, CA",
#                     "series_id": "PCPI06073",
#                     "value": "56116"
#                 },
#                 {
#                     "code": "06075",
#                     "region": "San Francisco County, CA",
#                     "series_id": "PCPI06075",
#                     "value": "113925"
#                 },
#                 {
#                     "code": "06077",
#                     "region": "San Joaquin County, CA",
#                     "series_id": "PCPI06077",
#                     "value": "40996"
#                 },
#                 {
#                     "code": "06079",
#                     "region": "San Luis Obispo County, CA",
#                     "series_id": "PCPI06079",
#                     "value": "52803"
#                 },
#                 {
#                     "code": "06081",
#                     "region": "San Mateo County, CA",
#                     "series_id": "PCPI06081",
#                     "value": "106615"
#                 },
#                 {
#                     "code": "06083",
#                     "region": "Santa Barbara County, CA",
#                     "series_id": "PCPI06083",
#                     "value": "57034"
#                 },
#                 {
#                     "code": "06085",
#                     "region": "Santa Clara County, CA",
#                     "series_id": "PCPI06085",
# ...
#                     "value": "44179"
#                 },
#                 {
#                     "code": "55041",
#                     "region": "Forest County, WI",
#                     "series_id": "PCPI55041",
#                     "value": "37892"
#                 },
#                 {
#                     "code": "55043",
#                     "region": "Grant County, WI",
#                     "series_id": "PCPI55043",
#                     "value": "39827"
#                 },
#                 {
#                     "code": "55045",
#                     "region": "Green County, WI",
#                     "series_id": "PCPI55045",
#                     "value": "47628"
#                 },
#                 {
#                     "code": "55047",
#                     "region": "Green Lake County, WI",
#                     "series_id": "PCPI55047",
#                     "value": "43477"
#                 },
#                 {
#                     "code": "55049",
#                     "region": "Iowa County, WI",
#                     "series_id": "PCPI55049",
#                     "value": "45092"
#                 },
#                 {
#                     "code": "55051",
#                     "region": "Iron County, WI",
#                     "series_id": "PCPI55051",
#                     "value": "46700"
#                 },
#                 {
#                     "code": "55053",
#                     "region": "Jackson County, WI",
#                     "series_id": "PCPI55053",
#                     "value": "41181"
#                 },
#                 {
#                     "code": "55055",
#                     "region": "Jefferson County, WI",
#                     "series_id": "PCPI55055",
#                     "value": "42399"
#                 },
#                 {
#                     "code": "55057",
#                     "region": "Juneau County, WI",
#                     "series_id": "PCPI55057",
#                     "value": "35107"
#                 },
#                 {
#                     "code": "55059",
#                     "region": "Kenosha County, WI",
#                     "series_id": "PCPI55059",
#                     "value": "43284"
#                 },
#                 {
#                     "code": "55061",
#                     "region": "Kewaunee County, WI",
#                     "series_id": "PCPI55061",
#                     "value": "43789"
#                 },
#                 {
#                     "code": "55063",
#                     "region": "La Crosse County, WI",
#                     "series_id": "PCPI55063",
#                     "value": "45985"
#                 },
#                 {
#                     "code": "55065",
#                     "region": "Lafayette County, WI",
#                     "series_id": "PCPI55065",
#                     "value": "41450"
#                 },
#                 {
#                     "code": "55067",
#                     "region": "Langlade County, WI",
#                     "series_id": "PCPI55067",
#                     "value": "40308"
#                 },
#                 {
#                     "code": "55069",
#                     "region": "Lincoln County, WI",
#                     "series_id": "PCPI55069",
#                     "value": "42450"
#                 },
#                 {
#                     "code": "55071",
#                     "region": "Manitowoc County, WI",
#                     "series_id": "PCPI55071",
#                     "value": "44546"
#                 },
#                 {
#                     "code": "55073",
#                     "region": "Marathon County, WI",
#                     "series_id": "PCPI55073",
#                     "value": "46201"
#                 },
#                 {
#                     "code": "55075",
#                     "region": "Marinette County, WI",
#                     "series_id": "PCPI55075",
#                     "value": "40892"
#                 },
#                 {
#                     "code": "55077",
#                     "region": "Marquette County, WI",
#                     "series_id": "PCPI55077",
#                     "value": "38191"
#                 },
#                 {
#                     "code": "55078",
#                     "region": "Menominee County, WI",
#                     "series_id": "PCPI55078",
#                     "value": "28748"
#                 },
#                 {
#                     "code": "55079",
#                     "region": "Milwaukee County, WI",
#                     "series_id": "PCPI55079",
#                     "value": "43621"
#                 },
#                 {
#                     "code": "55081",
#                     "region": "Monroe County, WI",
#                     "series_id": "PCPI55081",
#                     "value": "38091"
#                 },
#                 {
#                     "code": "55083",
#                     "region": "Oconto County, WI",
#                     "series_id": "PCPI55083",
#                     "value": "43130"
#                 },
#                 {
#                     "code": "55085",
#                     "region": "Oneida County, WI",
#                     "series_id": "PCPI55085",
#                     "value": "46168"
#                 },
#                 {
#                     "code": "55087",
#                     "region": "Outagamie County, WI",
#                     "series_id": "PCPI55087",
#                     "value": "47870"
#                 },
#                 {
#                     "code": "55089",
#                     "region": "Ozaukee County, WI",
#                     "series_id": "PCPI55089",
#                     "value": "77080"
#                 },
#                 {
#                     "code": "55091",
#                     "region": "Pepin County, WI",
#                     "series_id": "PCPI55091",
#                     "value": "44624"
#                 },
#                 {
#                     "code": "55093",
#                     "region": "Pierce County, WI",
#                     "series_id": "PCPI55093",
#                     "value": "43488"
#                 },
#                 {
#                     "code": "55095",
#                     "region": "Polk County, WI",
#                     "series_id": "PCPI55095",
#                     "value": "43337"
#                 },
#                 {
#                     "code": "55097",
#                     "region": "Portage County, WI",
#                     "series_id": "PCPI55097",
#                     "value": "42240"
#                 },
#                 {
#                     "code": "55099",
#                     "region": "Price County, WI",
#                     "series_id": "PCPI55099",
#                     "value": "43161"
#                 },
#                 {
#                     "code": "55101",
#                     "region": "Racine County, WI",
#                     "series_id": "PCPI55101",
#                     "value": "45037"
#                 },
#                 {
#                     "code": "55103",
#                     "region": "Richland County, WI",
#                     "series_id": "PCPI55103",
#                     "value": "40651"
#                 },
#                 {
#                     "code": "55105",
#                     "region": "Rock County, WI",
#                     "series_id": "PCPI55105",
#                     "value": "40825"
#                 },
#                 {
#                     "code": "55107",
#                     "region": "Rusk County, WI",
#                     "series_id": "PCPI55107",
#                     "value": "41026"
#                 },
#                 {
#                     "code": "55109",
#                     "region": "St. Croix County, WI",
#                     "series_id": "PCPI55109",
#                     "value": "51184"
#                 },
#                 {
#                     "code": "55111",
#                     "region": "Sauk County, WI",
#                     "series_id": "PCPI55111",
#                     "value": "44540"
#                 },
#                 {
#                     "code": "55113",
#                     "region": "Sawyer County, WI",
#                     "series_id": "PCPI55113",
#                     "value": "42272"
#                 },
#                 {
#                     "code": "55115",
#                     "region": "Shawano County, WI",
#                     "series_id": "PCPI55115",
#                     "value": "39037"
#                 },
#                 {
#                     "code": "55117",
#                     "region": "Sheboygan County, WI",
#                     "series_id": "PCPI55117",
#                     "value": "47867"
#                 },
#                 {
#                     "code": "55119",
#                     "region": "Taylor County, WI",
#                     "series_id": "PCPI55119",
#                     "value": "37626"
#                 },
#                 {
#                     "code": "55121",
#                     "region": "Trempealeau County, WI",
#                     "series_id": "PCPI55121",
#                     "value": "41167"
#                 },
#                 {
#                     "code": "55123",
#                     "region": "Vernon County, WI",
#                     "series_id": "PCPI55123",
#                     "value": "37827"
#                 },
#                 {
#                     "code": "55125",
#                     "region": "Vilas County, WI",
#                     "series_id": "PCPI55125",
#                     "value": "49929"
#                 },
#                 {
#                     "code": "55127",
#                     "region": "Walworth County, WI",
#                     "series_id": "PCPI55127",
#                     "value": "45311"
#                 },
#                 {
#                     "code": "55129",
#                     "region": "Washburn County, WI",
#                     "series_id": "PCPI55129",
#                     "value": "43714"
#                 },
#                 {
#                     "code": "55131",
#                     "region": "Washington County, WI",
#                     "series_id": "PCPI55131",
#                     "value": "53060"
#                 },
#                 {
#                     "code": "55133",
#                     "region": "Waukesha County, WI",
#                     "series_id": "PCPI55133",
#                     "value": "67231"
#                 },
#                 {
#                     "code": "55135",
#                     "region": "Waupaca County, WI",
#                     "series_id": "PCPI55135",
#                     "value": "42804"
#                 },
#                 {
#                     "code": "55137",
#                     "region": "Waushara County, WI",
#                     "series_id": "PCPI55137",
#                     "value": "37910"
#                 },
#                 {
#                     "code": "55139",
#                     "region": "Winnebago County, WI",
#                     "series_id": "PCPI55139",
#                     "value": "44583"
#                 },
#                 {
#                     "code": "55141",
#                     "region": "Wood County, WI",
#                     "series_id": "PCPI55141",
#                     "value": "43408"
#                 },
#                 {
#                     "code": "56001",
#                     "region": "Albany County, WY",
#                     "series_id": "PCPI56001",
#                     "value": "39845"
#                 },
#                 {
#                     "code": "56003",
#                     "region": "Big Horn County, WY",
#                     "series_id": "PCPI56003",
#                     "value": "35330"
#                 },
#                 {
#                     "code": "56005",
#                     "region": "Campbell County, WY",
#                     "series_id": "PCPI56005",
#                     "value": "47154"
#                 },
#                 {
#                     "code": "56007",
#                     "region": "Carbon County, WY",
#                     "series_id": "PCPI56007",
#                     "value": "50699"
#                 },
#                 {
#                     "code": "56009",
#                     "region": "Converse County, WY",
#                     "series_id": "PCPI56009",
#                     "value": "48292"
#                 },
#                 {
#                     "code": "56011",
#                     "region": "Crook County, WY",
#                     "series_id": "PCPI56011",
#                     "value": "44371"
#                 },
#                 {
#                     "code": "56013",
#                     "region": "Fremont County, WY",
#                     "series_id": "PCPI56013",
#                     "value": "40502"
#                 },
#                 {
#                     "code": "56015",
#                     "region": "Goshen County, WY",
#                     "series_id": "PCPI56015",
#                     "value": "40553"
#                 },
#                 {
#                     "code": "56017",
#                     "region": "Hot Springs County, WY",
#                     "series_id": "PCPI56017",
#                     "value": "52550"
#                 },
#                 {
#                     "code": "56019",
#                     "region": "Johnson County, WY",
#                     "series_id": "PCPI56019",
#                     "value": "47615"
#                 },
#                 {
#                     "code": "56021",
#                     "region": "Laramie County, WY",
#                     "series_id": "PCPI56021",
#                     "value": "48718"
#                 },
#                 {
#                     "code": "56023",
#                     "region": "Lincoln County, WY",
#                     "series_id": "PCPI56023",
#                     "value": "39501"
#                 },
#                 {
#                     "code": "56025",
#                     "region": "Natrona County, WY",
#                     "series_id": "PCPI56025",
#                     "value": "64858"
#                 },
#                 {
#                     "code": "56027",
#                     "region": "Niobrara County, WY",
#                     "series_id": "PCPI56027",
#                     "value": "42656"
#                 },
#                 {
#                     "code": "56029",
#                     "region": "Park County, WY",
#                     "series_id": "PCPI56029",
#                     "value": "48980"
#                 },
#                 {
#                     "code": "56031",
#                     "region": "Platte County, WY",
#                     "series_id": "PCPI56031",
#                     "value": "45304"
#                 },
#                 {
#                     "code": "56033",
#                     "region": "Sheridan County, WY",
#                     "series_id": "PCPI56033",
#                     "value": "53910"
#                 },
#                 {
#                     "code": "56035",
#                     "region": "Sublette County, WY",
#                     "series_id": "PCPI56035",
#                     "value": "47389"
#                 },
#                 {
#                     "code": "56037",
#                     "region": "Sweetwater County, WY",
#                     "series_id": "PCPI56037",
#                     "value": "47555"
#                 },
#                 {
#                     "code": "56039",
#                     "region": "Teton County, WY",
#                     "series_id": "PCPI56039",
#                     "value": "224366"
#                 },
#                 {
#                     "code": "56041",
#                     "region": "Uinta County, WY",
#                     "series_id": "PCPI56041",
#                     "value": "37866"
#                 },
#                 {
#                     "code": "56043",
#                     "region": "Washakie County, WY",
#                     "series_id": "PCPI56043",
#                     "value": "44204"
#                 },
#                 {
#                     "code": "56045",
#                     "region": "Weston County, WY",
#                     "series_id": "PCPI56045",
#                     "value": "42727"
#                 }
#             ]
#         },
#         "frequency": "Annual",
#         "region": "county",
#         "seasonality": "Not Seasonally Adjusted",
#         "title": "Per Capita Personal Income by County (Dollars)",
#         "units": "Dollars"
#     }
# }

# %%
region=response_json["meta"]["data"]["2016"]["region"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-ed4f013c68ac> in <module>
# ----> 1 region=response_json["meta"]["data"]["2016"]["region"]
#
# TypeError: list indices must be integers or slices, not str

# %%
# #add data to dataframe
# code=[]
# region=[]
# series_id=[]
# value=[]
# for code

# %%
api_df=DataFrame(response_json)
api_df
# Out:
#                                                           meta
# data         {'2016': [{'region': 'Autauga County, AL', 'co...
# frequency                                               Annual
# region                                                  county
# seasonality                            Not Seasonally Adjusted
# title           Per Capita Personal Income by County (Dollars)
# units                                                  Dollars

# %%
income_xl = pd.ExcelFile('Resources/county income level PROJECT.xlsx')
income_df = pd.read_excel(income_xl, skiprows = [1,2,3,4,5,6,])
income_df.head()
# Out:
#   Unnamed: 0 Table 1. Per Capita Personal Income by County, 2015 - 2017  \
# 0    Alabama                                            Autauga
# 1    Alabama                                            Baldwin
# 2    Alabama                                            Barbour
# 3    Alabama                                               Bibb
# 4    Alabama                                             Blount
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0     38591.0     39509.0     40484.0          9         2.4         2.5
# 1     41412.0     43004.0     44079.0          4         3.8         2.5
# 2     31509.0     31750.0     33453.0         46         0.8         5.4
# 3     29048.0     28989.0     30022.0         66        -0.2         3.6
# 4     31987.0     32261.0     33707.0         45         0.9         4.5
#
#   Unnamed: 8
# 0         67
# 1         66
# 2         11
# 3         47
# 4         19

# %%
income_df.rename(columns={ income_df.columns[2]: "2015($)" }, inplace = True)
income_df.rename(columns={ income_df.columns[3]: "2016($)" }, inplace = True)
income_df.rename(columns={ income_df.columns[4]: "2017($)" }, inplace = True)
income_df.rename(columns = {income_df.columns[0]: "State"}, inplace = True)
income_df.rename(columns = {income_df.columns[1]: "County"}, inplace = True)

income_df.head()
# Out:
#      State   County  2015($)  2016($)  2017($) Unnamed: 5  Unnamed: 6  \
# 0  Alabama  Autauga  38591.0  39509.0  40484.0          9         2.4
# 1  Alabama  Baldwin  41412.0  43004.0  44079.0          4         3.8
# 2  Alabama  Barbour  31509.0  31750.0  33453.0         46         0.8
# 3  Alabama     Bibb  29048.0  28989.0  30022.0         66        -0.2
# 4  Alabama   Blount  31987.0  32261.0  33707.0         45         0.9
#
#    Unnamed: 7 Unnamed: 8
# 0         2.5         67
# 1         2.5         66
# 2         5.4         11
# 3         3.6         47
# 4         4.5         19

# %%
year2015_data = income_df["2015($)"]
year2016_data = income_df["2016($)"]
year2017_data = income_df["2017($)"]

income_state_name=income_df["State"]
income_county=income_df["County"]

# %%
rename_income_df= pd.DataFrame({"State": income_state_name,
                        "County": income_county,
#                         "2015($)": year2015_data,
                        "Income Per Capita 2016 ($)": year2016_data,
#                         "2017($)": year2017_data,
                       })
rename_income_df.head()
# Out:
#      State   County  Income Per Capita 2016 ($)
# 0  Alabama  Autauga                     39509.0
# 1  Alabama  Baldwin                     43004.0
# 2  Alabama  Barbour                     31750.0
# 3  Alabama     Bibb                     28989.0
# 4  Alabama   Blount                     32261.0

# %%
merge_states_info = pd.merge(formatted_df, rename_income_df, 
                             right_on=["State", "County"], left_on = ["State", "County"])
merge_states_info.head()
# Out:
#      State State Abbr   County  Unemployment (%)  Obesity (%)  \
# 0  Alabama         AL  Autauga          5.883047         30.9
# 1  Alabama         AL  Baldwin          6.053720         26.7
# 2  Alabama         AL  Barbour         10.809275         40.8
# 3  Alabama         AL     Bibb          7.137850         40.1
# 4  Alabama         AL   Blount          6.146908         32.4
#
#    Some College (%)  High School Graduate (%)  Income Per Capita 2016 ($)
# 0         56.470750                 83.000000                     39509.0
# 1         62.335918                 80.000000                     43004.0
# 2         43.358568                 80.530303                     31750.0
# 3         48.927875                 81.000000                     28989.0
# 4         49.149934                 84.975362                     32261.0

# %%
SNAP = pd.ExcelFile('Resources/cntysnap.xls')
SNAP_df = pd.read_excel(SNAP, skiprows=2)
SNAP_df = SNAP_df.join(SNAP_df["Name"].str.split(",", 1, expand=True).rename(columns={0:'County', 1:'State Abbr'}))
SNAP_df["County"] = SNAP_df["County"].str.replace("County", "")
SNAP_df.head()
# Out:
#    State FIPS code  County FIPS code                Name  July 2016  \
# 0                1                 0             Alabama   813769.0
# 1                1                 1  Autauga County, AL     7844.0
# 2                1                 3  Baldwin County, AL    21406.0
# 3                1                 5  Barbour County, AL     6675.0
# 4                1                 7     Bibb County, AL     3740.0
#
#    July 2015  July 2014  July 2013  July 2012  July 2011  July 2010  ...  \
# 0   864350.0   893684.0   905604.0   914740.0   905658.0   859695.0  ...
# 1     8015.0     8145.0     8055.0     8079.0     8060.0     7593.0  ...
# 2    22920.0    24563.0    24402.0    23169.0    22184.0    20604.0  ...
# 3     6730.0     6725.0     6740.0     6843.0     6465.0     6324.0  ...
# 4     3794.0     4085.0     4175.0     4269.0     4336.0     4152.0  ...
#
#    July 2001  July 2000  July 1999  July 1998  July 1997  July 1995  \
# 0   435235.0   405325.0   396931.0   409160.0   434632.0   510271.0
# 1     3035.0     2814.0     2700.0     2589.0     2771.0     3611.0
# 2     4129.0     4178.0     4372.0     4850.0     5201.0     6928.0
# 3     4637.0     4415.0     4490.0     4788.0     4947.0     5268.0
# 4     1765.0     1685.0     1631.0     1776.0     1999.0     2085.0
#
#    July 1993  July 1989    County  State Abbr
# 0   561128.0   435296.0   Alabama        None
# 1     4608.0     3739.0  Autauga           AL
# 2     8053.0     5548.0  Baldwin           AL
# 3     5499.0     5056.0  Barbour           AL
# 4     2503.0     2056.0     Bibb           AL
#
# [5 rows x 28 columns]

# %%
reduced_SNAP_df = SNAP_df.loc[:, ["State Abbr", "County", "July 2016"]]
reduced_SNAP_df.rename(columns={"July 2016": "Number of SNAP Recipents"}, inplace=True)
reduced_SNAP_df = reduced_SNAP_df[reduced_SNAP_df["State Abbr"].astype(str) != "None"]

reduced_SNAP_df.head()
# Out:
#   State Abbr    County  Number of SNAP Recipents
# 1         AL  Autauga                     7844.0
# 2         AL  Baldwin                    21406.0
# 3         AL  Barbour                     6675.0
# 4         AL     Bibb                     3740.0
# 5         AL   Blount                     7037.0

# %%
reduced_SNAP_df['State Abbr'] = reduced_SNAP_df['State Abbr'].str.strip()
reduced_SNAP_df['County'] = reduced_SNAP_df['County'].str.strip()
merge_states_info['State Abbr'] = merge_states_info['State Abbr'].str.strip()
merge_states_info['County'] = merge_states_info['County'].str.strip()
all_merged_df = pd.merge(merge_states_info, reduced_SNAP_df, 
                         right_on = ["State Abbr","County"], left_on = ["State Abbr","County"])
all_merged_df.head()
# for x in merge_states_info['County'].astype('str'):
#      print(f'"{x}"')

# merge_states_info.dtypes
# merge_states_info.loc[[0,1,2],:]
# Out:
#      State State Abbr   County  Unemployment (%)  Obesity (%)  \
# 0  Alabama         AL  Autauga          5.883047         30.9
# 1  Alabama         AL  Baldwin          6.053720         26.7
# 2  Alabama         AL  Barbour         10.809275         40.8
# 3  Alabama         AL     Bibb          7.137850         40.1
# 4  Alabama         AL   Blount          6.146908         32.4
#
#    Some College (%)  High School Graduate (%)  Income Per Capita 2016 ($)  \
# 0         56.470750                 83.000000                     39509.0
# 1         62.335918                 80.000000                     43004.0
# 2         43.358568                 80.530303                     31750.0
# 3         48.927875                 81.000000                     28989.0
# 4         49.149934                 84.975362                     32261.0
#
#    Number of SNAP Recipents
# 0                    7844.0
# 1                   21406.0
# 2                    6675.0
# 3                    3740.0
# 4                    7037.0

# %%
#import excel file with obesity, unemployment, education
xls_Pop = pd.ExcelFile('Resources/County_Population_2016.xlsx')
Pop_df = pd.read_excel(xls_Pop)
Pop_df.head()
# Out:
#      State  Population   County
# 0  Alabama       55242  Autauga
# 1  Alabama      207712  Baldwin
# 2  Alabama       25819  Barbour
# 3  Alabama       22576     Bibb
# 4  Alabama       57517   Blount

# %%
#Merge County Pop data and SNAP data
merge_pop_info = pd.merge(Pop_df, all_merged_df, 
                             right_on=["State", "County"], left_on = ["State", "County"])

merge_pop_info.head()
# Out:
#      State  Population   County State Abbr  Unemployment (%)  Obesity (%)  \
# 0  Alabama       55242  Autauga         AL          5.883047         30.9
# 1  Alabama      207712  Baldwin         AL          6.053720         26.7
# 2  Alabama       25819  Barbour         AL         10.809275         40.8
# 3  Alabama       22576     Bibb         AL          7.137850         40.1
# 4  Alabama       57517   Blount         AL          6.146908         32.4
#
#    Some College (%)  High School Graduate (%)  Income Per Capita 2016 ($)  \
# 0         56.470750                 83.000000                     39509.0
# 1         62.335918                 80.000000                     43004.0
# 2         43.358568                 80.530303                     31750.0
# 3         48.927875                 81.000000                     28989.0
# 4         49.149934                 84.975362                     32261.0
#
#    Number of SNAP Recipents
# 0                    7844.0
# 1                   21406.0
# 2                    6675.0
# 3                    3740.0
# 4                    7037.0

# %%
#Calculate SNAP percentage based on County

SNAP_Percent=merge_pop_info["Number of SNAP Recipents"]/merge_pop_info["Population"]*100
# SNAP_Percent.head()

merge_pop_info['SNAP Recipents (%)'] = SNAP_Percent
merge_pop_info.head()
# Out:
#      State  Population   County State Abbr  Unemployment (%)  Obesity (%)  \
# 0  Alabama       55242  Autauga         AL          5.883047         30.9
# 1  Alabama      207712  Baldwin         AL          6.053720         26.7
# 2  Alabama       25819  Barbour         AL         10.809275         40.8
# 3  Alabama       22576     Bibb         AL          7.137850         40.1
# 4  Alabama       57517   Blount         AL          6.146908         32.4
#
#    Some College (%)  High School Graduate (%)  Income Per Capita 2016 ($)  \
# 0         56.470750                 83.000000                     39509.0
# 1         62.335918                 80.000000                     43004.0
# 2         43.358568                 80.530303                     31750.0
# 3         48.927875                 81.000000                     28989.0
# 4         49.149934                 84.975362                     32261.0
#
#    Number of SNAP Recipents  SNAP Recipents (%)
# 0                    7844.0           14.199341
# 1                   21406.0           10.305615
# 2                    6675.0           25.853054
# 3                    3740.0           16.566265
# 4                    7037.0           12.234644

# %%
final_data=merge_pop_info.loc[:, ["State", "State Abbr", "County", "Unemployment (%)", "Obesity (%)", 
                                  "Some College (%)", "High School Graduate (%)", "SNAP Recipents (%)", 
                                  "Income Per Capita 2016 ($)"]]

final_data.head()
# Out:
#      State State Abbr   County  Unemployment (%)  Obesity (%)  \
# 0  Alabama         AL  Autauga          5.883047         30.9
# 1  Alabama         AL  Baldwin          6.053720         26.7
# 2  Alabama         AL  Barbour         10.809275         40.8
# 3  Alabama         AL     Bibb          7.137850         40.1
# 4  Alabama         AL   Blount          6.146908         32.4
#
#    Some College (%)  High School Graduate (%)  SNAP Recipents (%)  \
# 0         56.470750                 83.000000           14.199341
# 1         62.335918                 80.000000           10.305615
# 2         43.358568                 80.530303           25.853054
# 3         48.927875                 81.000000           16.566265
# 4         49.149934                 84.975362           12.234644
#
#    Income Per Capita 2016 ($)
# 0                     39509.0
# 1                     43004.0
# 2                     31750.0
# 3                     28989.0
# 4                     32261.0

# %%
final_data.count()
# Out:
# State                         2966
# State Abbr                    2966
# County                        2966
# Unemployment (%)              2966
# Obesity (%)                   2966
# Some College (%)              2966
# High School Graduate (%)      2484
# SNAP Recipents (%)            2966
# Income Per Capita 2016 ($)    2966
# dtype: int64

# %%
#drop rows missing data
final_data.dropna(inplace=True)

# %%
final_data.count()
# Out:
# State                         2484
# State Abbr                    2484
# County                        2484
# Unemployment (%)              2484
# Obesity (%)                   2484
# Some College (%)              2484
# High School Graduate (%)      2484
# SNAP Recipents (%)            2484
# Income Per Capita 2016 ($)    2484
# dtype: int64

# %%
#Get sample of 30% of population
sample = final_data.sample(frac =.30)
sample.head()
# Out:
#            State State Abbr       County  Unemployment (%)  Obesity (%)  \
# 1016    Kentucky         KY      Madison          5.399987         29.6
# 2782  Washington         WA        Clark          7.852223         30.0
# 2812  Washington         WA  Walla Walla          6.516592         26.1
# 104     Arkansas         AR     Lawrence          7.406348         33.3
# 1069       Maine         ME       Oxford          6.993312         31.7
#
#       Some College (%)  High School Graduate (%)  SNAP Recipents (%)  \
# 1016         67.597273                 92.496863           12.717712
# 2782         64.369803                 80.071547           13.058176
# 2812         63.571889                 76.475694           14.873365
# 104          47.641387                 93.955823           16.163133
# 1069         50.099880                 82.387387           18.734921
#
#       Income Per Capita 2016 ($)
# 1016                     33942.0
# 2782                     48305.0
# 2812                     42121.0
# 104                      31525.0
# 1069                     35050.0

# %%
sample.count()
# Out:
# State                         745
# State Abbr                    745
# County                        745
# Unemployment (%)              745
# Obesity (%)                   745
# Some College (%)              745
# High School Graduate (%)      745
# SNAP Recipents (%)            745
# Income Per Capita 2016 ($)    745
# dtype: int64

# %%
#Obesity vs Unemployment
#obtain the x and y coordinates for x and y coordinates

#get limits for x axis
x_limit_min = sample["Obesity (%)"].min()
# x_limit_min
x_limit_max = sample["Obesity (%)"].max()
# x_limit_max


#graphing for Obesity vs Unemployment
#max unemployment limits
unemp_limit_min = sample["Unemployment (%)"].min()
# unemp_limit_min
unemp_limit_max = sample["Unemployment (%)"].max()
# unemp_limit_max

#Obesity vs Unemployment
obesity_vs_unemp = plt.scatter(sample["Obesity (%)"], sample["Unemployment (%)"], marker="o", 
                               facecolors="blue", edgecolors="black", s=30, alpha=0.75)
plt.scatter

# Incorporate the other graph properties

# Set your x and y limits
plt.xlim(x_limit_min-2, x_limit_max+2)
plt.ylim(unemp_limit_min-2, unemp_limit_max+2)

#label x and y axis

plt.xlabel("Obesity (%)")
plt.ylabel("Unemployment (%)")

#add header
plt.title(f"Obesity Rate vs. Unemployment Rate by County (2016)")

#add trendline
sns.regplot(sample["Obesity (%)"],sample["Unemployment (%)"])


# Set a grid on the plot
plt.grid()

# Save Figure
plt.savefig("Obesity_vs_Unemployment.png")

# Show plot
plt.show()
