# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import xlrd 


# # Import API key
# from api_keys import api_key

# %%
#import excel file with obesity, unemployment, education
xls = pd.ExcelFile('Resources/2019 County Health Rankings Data - v2.xls')
df = pd.read_excel(xls, 'Ranked Measure Data', skiprows=1)

# %%
df.head()
# Out:
#    FIPS    State   County  Years of Potential Life Lost Rate  95% CI - Low  \
# 0  1001  Alabama  Autauga                        8824.057123   7935.325829
# 1  1003  Alabama  Baldwin                        7224.632160   6794.128380
# 2  1005  Alabama  Barbour                        9586.165037   8200.117541
# 3  1007  Alabama     Bibb                       11783.543675  10159.978321
# 4  1009  Alabama   Blount                       10908.101822   9895.582572
#
#    95% CI - High Quartile  YPLL Rate (Black)  YPLL Rate (Hispanic)  \
# 0    9712.788417        1       10471.252986                   NaN
# 1    7655.135940        1       10042.472874           3086.605695
# 2   10972.212533        1       11332.562909                   NaN
# 3   13407.109028        3       14812.539280                   NaN
# 4   11920.621071        3                NaN           5619.645186
#
#    YPLL Rate (White)  ...  95% CI - High.17  Quartile.33  \
# ...

# %%
clean_df=df.drop(df.index[1])


# obesity_percent=df[‘col34']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e88427a0472c> in <module>
# ----> 1 clean_df=df.drop(df.index[1])
#       2
#       3
#       4 # obesity_percent=df[‘col34']
#
# NameError: name 'df' is not defined
